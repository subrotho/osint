# %%
import newspaper as nwp

# %%
from newspaper import Article

# %%
>>> url = 'https://www.oxfordeconomics.com/recent-releases/The-Projected-Economic-Impact-of-COVID-19-on-the-UK-Creative-Industries'
>>> article = Article(url)

# %%
article.download()

# %%
article.html
# Out:
# '<!DOCTYPE html><html lang="en-US" dir="ltr"><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><link rel="shortcut icon" type="image/x-icon" href="/static/extras/favicon.ico"/><link href="https://fonts.googleapis.com/css?family=Montserrat:400,700" rel="stylesheet"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/normalize/8.0.1/normalize.min.css"/><script src="/static/js/polyfill.js"></script><meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1"/><meta charSet="utf-8"/><meta name="description" content="Releases of our latest economic analysis and reports"/><meta name="twitter:description" content="Releases of our latest economic analysis and reports"/><meta property="og:description" content="Releases of our latest economic analysis and reports"/><title>The Projected Economic Impact of COVID-19 on the U.K. Creative Ind
# ...

# %%
article.parse()

# %%
article.authors
# Out:
# []

# %%
article.publish_date

# %%
article.text
# Out:
# 'This report explores the short-term effects of Covid-19 on the financial sustainability of the creative industries in the UK.\n\nAlong with the tourism sector, Creative Industries (CIs) are among the most affected by the current Covid-19 crisis. Creative workers, one of the more vulnerable sectors of the workforce, are already seeing devastating impacts on their income, not only in turnover terms, but also in their charitable contributions and sponsorship. Leaving behind the more fragile part of the sector could cause irreparable socio-economic damage.\n\nWe find that the Creative Industries are projecting a combined £77bn turnover loss over the course of 2020 compared to 2019 (-31%). This is expected to translate into a GVA shortfall of £29bn in 2020 compared to 2019 (-26%), over half of which is in London.\n\nIn 2020, CIs are projecting a 122,000 drop in employment among employees (despite the Coronavirus Job Retention Scheme - JRS) and a further 287,000 job losses among self empl
# ...

# %%
article.top_image
# Out:
# 'https://bsmedia.business-standard.com/_media/bs/img/article/2017-04/26/full/1493228932-3912.jpg'

# %%
article.movies
# Out:
# []

# %%
>>> import nltk
>>> nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
article.nlp()

# %%
b = article.keywords

# %%
b
# Out:
# ['job',
#  'worse',
#  'staff',
#  'jobs',
#  'support',
#  'losses',
#  'rate',
#  'ahead',
#  'seen',
#  'winds',
#  'working',
#  'decadehigh',
#  'work',
#  'hit',
#  'market',
#  'uk',
#  'cent',
#  'impact',
#  'covid19']

# %%
article.summary
# Out:
# "UK unemployment rose to its highest level since 2016 in the three months through September as the COVID-19 pandemic forced employers to shed workers, the Office for National Statistics said Tuesday.\nThe unemployment rate increased to 4.8% in the period, up 0.3 percentage points from last month and a full percentage point from a year earlier, the ONS said.\nThe figure is still well below the peak of 8.5% reached in late 2011 after the global financial crisis.\nToday's figures underline the scale of the challenge we're facing,'' Treasury chief Rishi Sunak said in a statement.\n(Only the headline and picture of this report may have been reworked by the Business Standard staff; the rest of the content is auto-generated from a syndicated feed.)"
